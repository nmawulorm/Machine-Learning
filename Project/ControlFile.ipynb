# %%
import pandas as pd

data = pd.read_csv('data.csv')
df = pd.read_csv('data.csv')
print(data.head())
data.describe()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
    from sklearn.preprocessing import LabelEncoder
    
    le = LabelEncoder()
    df['diagnosis'] = le.fit_transform(df['diagnosis'])
    
    m_diagnosis_df = df[df['diagnosis'] == 'M']
    
    # calculate the mean of each column
    averages = m_diagnosis_df.mean()
    
    print(averages)
# Out:
# id                        NaN
# diagnosis                 NaN
# radius_mean               NaN
# texture_mean              NaN
# perimeter_mean            NaN
# area_mean                 NaN
# smoothness_mean           NaN
# compactness_mean          NaN
# concavity_mean            NaN
# concave points_mean       NaN
# symmetry_mean             NaN
# fractal_dimension_mean    NaN
# radius_se                 NaN
# texture_se                NaN
# perimeter_se              NaN
# area_se                   NaN
# smoothness_se             NaN
# compactness_se            NaN
# concavity_se              NaN
# concave points_se         NaN
# symmetry_se               NaN
# fractal_dimension_se      NaN
# radius_worst              NaN
# texture_worst             NaN
# perimeter_worst           NaN
# area_worst                NaN
# smoothness_worst          NaN
# compactness_worst         NaN
# concavity_worst           NaN
# concave points_worst      NaN
# symmetry_worst            NaN
# ...

# %%
import numpy as np

numerical_cols = df.select_dtypes(include=[np.number]).columns
print(df[numerical_cols].describe())
df[numerical_cols].describe()

df.head()
# Out:
#                  id   diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  5.690000e+02  569.000000   569.000000    569.000000      569.000000
# mean   3.037183e+07    0.372583    14.127292     19.289649       91.969033
# std    1.250206e+08    0.483918     3.524049      4.301036       24.298981
# min    8.670000e+03    0.000000     6.981000      9.710000       43.790000
# 25%    8.692180e+05    0.000000    11.700000     16.170000       75.170000
# 50%    9.060240e+05    0.000000    13.370000     18.840000       86.240000
# 75%    8.813129e+06    1.000000    15.780000     21.800000      104.100000
# max    9.113205e+08    1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   569.000000       569.000000        569.000000      569.000000
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.914129         0.014064          0.052813        0.079720
# ...

# %%
averages = m_diagnosis_df.mean(axis=0)
print(averages)
# Out:
# id                        NaN
# diagnosis                 NaN
# radius_mean               NaN
# texture_mean              NaN
# perimeter_mean            NaN
# area_mean                 NaN
# smoothness_mean           NaN
# compactness_mean          NaN
# concavity_mean            NaN
# concave points_mean       NaN
# symmetry_mean             NaN
# fractal_dimension_mean    NaN
# radius_se                 NaN
# texture_se                NaN
# perimeter_se              NaN
# area_se                   NaN
# smoothness_se             NaN
# compactness_se            NaN
# concavity_se              NaN
# concave points_se         NaN
# symmetry_se               NaN
# fractal_dimension_se      NaN
# radius_worst              NaN
# texture_worst             NaN
# perimeter_worst           NaN
# area_worst                NaN
# smoothness_worst          NaN
# compactness_worst         NaN
# concavity_worst           NaN
# concave points_worst      NaN
# symmetry_worst            NaN
# ...

# %% [markdown]
# Describing maligning data

# %%
numerical_cols = df.select_dtypes(include=[np.number]).columns
diagnosis_1_df = df[df['diagnosis'] == 1]
diagnosis_1_df[numerical_cols].describe()
# Out:
#                  id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  2.120000e+02      212.0   212.000000    212.000000      212.000000
# mean   3.681805e+07        1.0    17.462830     21.604906      115.365377
# std    1.378965e+08        0.0     3.203971      3.779470       21.854653
# min    8.670000e+03        1.0    10.950000     10.380000       71.900000
# 25%    8.613450e+05        1.0    15.075000     19.327500       98.745000
# 50%    8.953665e+05        1.0    17.325000     21.460000      114.200000
# 75%    8.911290e+06        1.0    19.590000     23.765000      129.925000
# max    9.112962e+08        1.0    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   212.000000       212.000000        212.000000      212.000000
# mean    978.376415         0.102898          0.145188        0.160775
# std     367.937978         0.012608          0.053987        0.075019
# ...

# %%
numerical_cols = df.select_dtypes(include=[np.number]).columns
diagnosis_1_df = df[df['diagnosis'] == 0]
diagnosis_1_df[numerical_cols].describe()
# Out:
#                  id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  3.570000e+02      357.0   357.000000    357.000000      357.000000
# mean   2.654382e+07        0.0    12.146524     17.914762       78.075406
# std    1.167397e+08        0.0     1.780512      3.995125       11.807438
# min    8.913000e+03        0.0     6.981000      9.710000       43.790000
# 25%    8.746620e+05        0.0    11.080000     15.150000       70.870000
# 50%    9.089160e+05        0.0    12.200000     17.390000       78.180000
# 75%    8.812816e+06        0.0    13.370000     19.760000       86.100000
# max    9.113205e+08        0.0    17.850000     33.810000      114.600000
#
#         area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count  357.000000       357.000000        357.000000      357.000000
# mean   462.790196         0.092478          0.080085        0.046058
# std    134.287118         0.013446          0.033750        0.043442
# ...
